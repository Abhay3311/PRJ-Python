# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay3311/PRJ-Python/blob/main/Sugar_Scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
candy_data =pd.read_csv("https://raw.githubusercontent.com/Abhay3311/PRJ-Python/main/candy.csv")
candy_data.head()
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'],hue=candy_data['chocolate'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lmplot(x='sugarpercent',y='winpercent',hue='chocolate',data= candy_data)
plt.show()

# %%
plt.figure(figsize=(10,6));
sns.swarmplot(x=candy_data['chocolate'], y=candy_data['winpercent'])
plt.show()
